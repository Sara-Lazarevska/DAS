# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import csv
import re
import os
import time

# Load existing data to skip already-scraped entries
existing_data = set()
if os.path.exists("issuer_data.csv"):
    with open("issuer_data.csv", "r", encoding="utf-8") as csvfile:
        reader = csv.reader(csvfile)
        next(reader)  # Skip header
        for row in reader:
            # Create a unique key for each row (issuer + year)
            existing_data.add((row[0], int(row[1])))

# URL for the target page
base_url = "https://www.mse.mk/en/stats/symbolhistory/ALKB"
session = requests.Session()

# Get initial page
response = session.get(base_url)
soup = BeautifulSoup(response.text, "html.parser")

# Extract issuer codes from the dropdown menu
dropdown = soup.find(id="Code")
issuers = [
    option["value"]
    for option in dropdown.find_all("option")
    if option.get("value") and not re.search(r'\d', option["value"])
]
print("Issuers found:", issuers)

# Prepare CSV
with open("issuer_data.csv", "a", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    if not existing_data:  # Write header if file was empty
        writer.writerow(["Issuer", "Year", "Date", "Last trade price", "Max", "Min", "Avg.Price", "%chg.", "Volume", "Turnover in BEST in denars", "Total turnover in denars"])

    # Start timer for entire script
    script_start_time = time.time()

    # Loop through the last 10 years
    for i in range(10):
        year = datetime.now().year - i
        from_date = f"01/01/{year}"
        to_date = f"12/31/{year}"

        # Loop through each issuer
        for issuer in issuers:
            if (issuer, year) in existing_data:
                print(f"Skipping {issuer} for {year} as it already exists in the file.")
                continue  # Skip if data for this issuer and year already exists

            # Start timer for each issuer-year data retrieval
            retrieval_start_time = time.time()

            # Build payload with issuer and date range to fetch data
            payload = {
                "Code": issuer,
                "FromDate": from_date,
                "ToDate": to_date
            }

            try:
                # Submit request with date range and issuer
                data_response = session.post(base_url, data=payload)
                data_soup = BeautifulSoup(data_response.text, "html.parser")

                # Find the results table
                results_table = data_soup.find(id="resultsTable")
                if not results_table:
                    print(f"No data found for {issuer} in {year}")
                    continue

                # Extract rows of data from the table
                rows = results_table.find("tbody").find_all("tr")
                for row in rows:
                    columns = [cell.get_text(strip=True) for cell in row.find_all("td")]
                    if columns and any(columns):  # Skip empty rows
                        writer.writerow([issuer, year] + columns)

                # Calculate time taken for this retrieval
                retrieval_end_time = time.time()
                print(f"Data for {issuer} in {year} saved in {retrieval_end_time - retrieval_start_time:.2f} seconds.")

            except Exception as e:
                print(f"Error fetching data for {issuer} in {year}: {e}")
                continue

    # End timer for entire script
    script_end_time = time.time()
    print(f"Script completed in {script_end_time - script_start_time:.2f} seconds.")
# Out:
# Issuers found: ['ADIN', 'ALK', 'ALKB', 'AMBR', 'AMEH', 'APTK', 'ATPP', 'AUMK', 'BANA', 'BGOR', 'BIKF', 'BIM', 'BLTU', 'CBNG', 'CDHV', 'CEVI', 'CKB', 'CKBKO', 'DEBA', 'DIMI', 'EDST', 'ELMA', 'ELNC', 'ENER', 'ENSA', 'EUHA', 'EUMK', 'EVRO', 'FAKM', 'FERS', 'FKTL', 'FROT', 'FUBT', 'GALE', 'GDKM', 'GECK', 'GECT', 'GIMS', 'GRDN', 'GRNT', 'GRSN', 'GRZD', 'GTC', 'GTRG', 'IJUG', 'INB', 'INHO', 'INOV', 'INPR', 'INTP', 'JAKO', 'JUSK', 'KARO', 'KDFO', 'KJUBI', 'KKST', 'KLST', 'KMB', 'KMPR', 'KOMU', 'KONF', 'KONZ', 'KORZ', 'KPSS', 'KULT', 'KVAS', 'LAJO', 'LHND', 'LOTO', 'LOZP', 'MAGP', 'MAKP', 'MAKS', 'MB', 'MERM', 'MKSD', 'MLKR', 'MODA', 'MPOL', 'MPT', 'MPTE', 'MTUR', 'MZHE', 'MZPU', 'NEME', 'NOSK', 'OBPP', 'OILK', 'OKTA', 'OMOS', 'OPFO', 'OPTK', 'ORAN', 'OSPO', 'OTEK', 'PELK', 'PGGV', 'PKB', 'POPK', 'PPIV', 'PROD', 'PROT', 'PTRS', 'RADE', 'REPL', 'RIMI', 'RINS', 'RZEK', 'RZIT', 'RZIZ', 'RZLE', 'RZLV', 'RZTK', 'RZUG', 'RZUS', 'SBT', 'SDOM', 'SIL', 'SKON', 'SKP', 'SLAV', 'SNBT', 'SNBTO', 'SOLN', 'SPAZ', 'SPAZP', 'SPOL', 'SSPR', 'STB', 'STBP', 'STIL', 'STOK', 'TAJM', 'TBKO', 'TEAL', 'TEHN', 'TEL', 'TETE', 'TIKV', 'TKPR', 'TKVS', 'TNB', 'TRDB', 'TRPS', 'TRUB', 'TSMP', 'TSZS', 'TTK', 'TTKO', 'UNI', 'USJE', 'VARG', 'VFPM', 'VITA', 'VROS', 'VSC', 'VTKS', 'ZAS', 'ZILU', 'ZILUP', 'ZIMS', 'ZKAR', 'ZPKO', 'ZPOG', 'ZUAS']
# Data for ADIN in 2024 saved in 0.64 seconds.
# Data for ALK in 2024 saved in 0.37 seconds.
# Data for ALKB in 2024 saved in 0.30 seconds.
# Data for AMBR in 2024 saved in 0.24 seconds.
# Data for AMEH in 2024 saved in 0.46 seconds.
# Data for APTK in 2024 saved in 0.38 seconds.
# Data for ATPP in 2024 saved in 0.39 seconds.
# Data for AUMK in 2024 saved in 0.48 seconds.
# Data for BANA in 2024 saved in 0.38 seconds.
# Data for BGOR in 2024 saved in 0.39 seconds.
# Data for BIKF in 2024 saved in 0.37 seconds.
# Data for BIM in 2024 saved in 0.56 seconds.
# Data for BLTU in 2024 saved in 0.36 seconds.
# Data for CBNG in 2024 saved in 0.49 seconds.
# Data for CDHV in 2024 saved in 0.61 seconds.
# Data for CEVI in 2024 saved in 0.51 seconds.
# Data for CKB in 2024 saved in 0.52 seconds.
# Data for CKBKO in 2024 saved in 0.42 seconds.
# Data for DEBA in 2024 saved in 0.50 seconds.
# Data for DIMI in 2024 saved in 0.36 seconds.
# Data for EDST in 2024 saved in 0.39 seconds.
# Data for ELMA in 2024 saved in 0.23 seconds.
# Data for ELNC in 2024 saved in 0.43 seconds.
# Data for ENER in 2024 saved in 0.39 seconds.
# Data for ENSA in 2024 saved in 0.22 seconds.
# Data for EUHA in 2024 saved in 0.35 seconds.
# Data for EUMK in 2024 saved in 0.40 seconds.
# Data for EVRO in 2024 saved in 0.38 seconds.
# Data for FAKM in 2024 saved in 0.36 seconds.
# Data for FERS in 2024 saved in 0.39 seconds.
# Data for FKTL in 2024 saved in 0.49 seconds.
# Data for FROT in 2024 saved in 0.31 seconds.
# Data for FUBT in 2024 saved in 0.37 seconds.
# Data for GALE in 2024 saved in 0.32 seconds.
# Data for GDKM in 2024 saved in 0.50 seconds.
# Data for GECK in 2024 saved in 0.38 seconds.
# Data for GECT in 2024 saved in 0.38 seconds.
# Data for GIMS in 2024 saved in 0.51 seconds.
# Data for GRDN in 2024 saved in 0.37 seconds.
# Data for GRNT in 2024 saved in 0.39 seconds.
# Data for GRSN in 2024 saved in 0.25 seconds.
# Data for GRZD in 2024 saved in 0.49 seconds.
# Data for GTC in 2024 saved in 0.40 seconds.
# Data for GTRG in 2024 saved in 0.40 seconds.
# Data for IJUG in 2024 saved in 0.28 seconds.
# Data for INB in 2024 saved in 0.67 seconds.
# Data for INHO in 2024 saved in 0.52 seconds.
# Data for INOV in 2024 saved in 0.25 seconds.
# Data for INPR in 2024 saved in 0.49 seconds.
# Data for INTP in 2024 saved in 0.51 seconds.
# Data for JAKO in 2024 saved in 0.31 seconds.
# Data for JUSK in 2024 saved in 0.36 seconds.
# Data for KARO in 2024 saved in 0.37 seconds.
# Data for KDFO in 2024 saved in 0.44 seconds.
# Data for KJUBI in 2024 saved in 0.43 seconds.
# Data for KKST in 2024 saved in 0.36 seconds.
# Data for KLST in 2024 saved in 0.49 seconds.
# Data for KMB in 2024 saved in 0.40 seconds.
# Data for KMPR in 2024 saved in 0.41 seconds.
# Data for KOMU in 2024 saved in 0.44 seconds.
# Data for KONF in 2024 saved in 0.56 seconds.
# Data for KONZ in 2024 saved in 0.43 seconds.
# Data for KORZ in 2024 saved in 0.25 seconds.
# Data for KPSS in 2024 saved in 0.51 seconds.
# Data for KULT in 2024 saved in 0.37 seconds.
# Data for KVAS in 2024 saved in 0.37 seconds.
# Data for LAJO in 2024 saved in 0.33 seconds.
# Data for LHND in 2024 saved in 0.50 seconds.
# Data for LOTO in 2024 saved in 0.38 seconds.
# Data for LOZP in 2024 saved in 0.38 seconds.
# Data for MAGP in 2024 saved in 0.25 seconds.
# Data for MAKP in 2024 saved in 0.49 seconds.
# Data for MAKS in 2024 saved in 0.38 seconds.
# Data for MB in 2024 saved in 0.35 seconds.
# Data for MERM in 2024 saved in 0.55 seconds.
# Data for MKSD in 2024 saved in 0.69 seconds.
# Data for MLKR in 2024 saved in 0.52 seconds.
# Data for MODA in 2024 saved in 0.50 seconds.
# Data for MPOL in 2024 saved in 0.58 seconds.
# Data for MPT in 2024 saved in 0.41 seconds.
# Data for MPTE in 2024 saved in 0.25 seconds.
# Data for MTUR in 2024 saved in 0.39 seconds.
# Data for MZHE in 2024 saved in 0.41 seconds.
# Data for MZPU in 2024 saved in 0.50 seconds.
# Data for NEME in 2024 saved in 0.37 seconds.
# Data for NOSK in 2024 saved in 0.40 seconds.
# Data for OBPP in 2024 saved in 0.42 seconds.
# Data for OILK in 2024 saved in 0.40 seconds.
# Data for OKTA in 2024 saved in 0.39 seconds.
# Data for OMOS in 2024 saved in 0.28 seconds.
# Data for OPFO in 2024 saved in 0.49 seconds.
# Data for OPTK in 2024 saved in 0.40 seconds.
# Data for ORAN in 2024 saved in 0.40 seconds.
# Data for OSPO in 2024 saved in 0.33 seconds.
# Data for OTEK in 2024 saved in 0.48 seconds.
# Data for PELK in 2024 saved in 0.38 seconds.
# Data for PGGV in 2024 saved in 0.22 seconds.
# Data for PKB in 2024 saved in 0.40 seconds.
# Data for POPK in 2024 saved in 0.50 seconds.
# Data for PPIV in 2024 saved in 0.38 seconds.
# Data for PROD in 2024 saved in 0.37 seconds.
# Data for PROT in 2024 saved in 0.30 seconds.
# Data for PTRS in 2024 saved in 0.62 seconds.
# Data for RADE in 2024 saved in 0.50 seconds.
# Data for REPL in 2024 saved in 0.51 seconds.
# Data for RIMI in 2024 saved in 0.56 seconds.
# Data for RINS in 2024 saved in 0.51 seconds.
# Data for RZEK in 2024 saved in 0.36 seconds.
# Data for RZIT in 2024 saved in 0.39 seconds.
# Data for RZIZ in 2024 saved in 0.51 seconds.
# Data for RZLE in 2024 saved in 0.40 seconds.
# Data for RZLV in 2024 saved in 0.36 seconds.
# Data for RZTK in 2024 saved in 0.49 seconds.
# Data for RZUG in 2024 saved in 0.40 seconds.
# Data for RZUS in 2024 saved in 0.37 seconds.
# Data for SBT in 2024 saved in 0.37 seconds.
# Data for SDOM in 2024 saved in 0.50 seconds.
# Data for SIL in 2024 saved in 0.40 seconds.
# Data for SKON in 2024 saved in 0.24 seconds.
# Data for SKP in 2024 saved in 0.37 seconds.
# Data for SLAV in 2024 saved in 0.48 seconds.
# Data for SNBT in 2024 saved in 0.40 seconds.
# Data for SNBTO in 2024 saved in 0.39 seconds.
# Data for SOLN in 2024 saved in 0.50 seconds.
# Data for SPAZ in 2024 saved in 0.37 seconds.
# Data for SPAZP in 2024 saved in 0.38 seconds.
# Data for SPOL in 2024 saved in 0.37 seconds.
# Data for SSPR in 2024 saved in 0.52 seconds.
# Data for STB in 2024 saved in 0.38 seconds.
# Data for STBP in 2024 saved in 0.41 seconds.
# Data for STIL in 2024 saved in 0.52 seconds.
# Data for STOK in 2024 saved in 0.50 seconds.
# Data for TAJM in 2024 saved in 0.50 seconds.
# Data for TBKO in 2024 saved in 0.34 seconds.
# Data for TEAL in 2024 saved in 0.67 seconds.
# Data for TEHN in 2024 saved in 0.49 seconds.
# Data for TEL in 2024 saved in 0.38 seconds.
# Data for TETE in 2024 saved in 0.48 seconds.
# Data for TIKV in 2024 saved in 0.37 seconds.
# Data for TKPR in 2024 saved in 0.38 seconds.
# Data for TKVS in 2024 saved in 0.48 seconds.
# Data for TNB in 2024 saved in 0.39 seconds.
# Data for TRDB in 2024 saved in 0.37 seconds.
# Data for TRPS in 2024 saved in 0.39 seconds.
# Data for TRUB in 2024 saved in 0.51 seconds.
# Data for TSMP in 2024 saved in 0.36 seconds.
# Data for TSZS in 2024 saved in 0.38 seconds.
# Data for TTK in 2024 saved in 0.51 seconds.
# Data for TTKO in 2024 saved in 0.38 seconds.
# Data for UNI in 2024 saved in 0.38 seconds.
# Data for USJE in 2024 saved in 0.36 seconds.
# Data for VARG in 2024 saved in 0.57 seconds.
# Data for VFPM in 2024 saved in 0.40 seconds.
# Data for VITA in 2024 saved in 0.44 seconds.
# Data for VROS in 2024 saved in 0.49 seconds.
# Data for VSC in 2024 saved in 0.38 seconds.
# Data for VTKS in 2024 saved in 0.38 seconds.
# Data for ZAS in 2024 saved in 0.40 seconds.
# Data for ZILU in 2024 saved in 0.56 seconds.
# Data for ZILUP in 2024 saved in 0.42 seconds.
# Data for ZIMS in 2024 saved in 0.53 seconds.
# Data for ZKAR in 2024 saved in 0.65 seconds.
# Data for ZPKO in 2024 saved in 0.52 seconds.
# Data for ZPOG in 2024 saved in 0.48 seconds.
# Data for ZUAS in 2024 saved in 0.49 seconds.
# Data for ADIN in 2023 saved in 0.39 seconds.
# Data for ALK in 2023 saved in 0.40 seconds.
# Data for ALKB in 2023 saved in 0.55 seconds.
# No data found for AMBR in 2023
# Data for AMEH in 2023 saved in 0.43 seconds.
# Data for APTK in 2023 saved in 0.40 seconds.
# Data for ATPP in 2023 saved in 0.57 seconds.
# Data for AUMK in 2023 saved in 0.42 seconds.
# Data for BANA in 2023 saved in 0.41 seconds.
# Data for BGOR in 2023 saved in 0.52 seconds.
# No data found for BIKF in 2023
# Data for BIM in 2023 saved in 0.40 seconds.
# Data for BLTU in 2023 saved in 0.42 seconds.
# Data for CBNG in 2023 saved in 0.54 seconds.
# Data for CDHV in 2023 saved in 0.31 seconds.
# Data for CEVI in 2023 saved in 0.42 seconds.
# Data for CKB in 2023 saved in 0.39 seconds.
# Data for CKBKO in 2023 saved in 0.57 seconds.
# Data for DEBA in 2023 saved in 0.43 seconds.
# Data for DIMI in 2023 saved in 0.41 seconds.
# Data for EDST in 2023 saved in 0.57 seconds.
# No data found for ELMA in 2023
# No data found for ELNC in 2023
# Data for ENER in 2023 saved in 0.45 seconds.
# No data found for ENSA in 2023
# Data for EUHA in 2023 saved in 0.71 seconds.
# No data found for EUMK in 2023
# Data for EVRO in 2023 saved in 0.52 seconds.
# Data for FAKM in 2023 saved in 0.48 seconds.
# Data for FERS in 2023 saved in 0.56 seconds.
# Data for FKTL in 2023 saved in 0.27 seconds.
# Data for FROT in 2023 saved in 0.39 seconds.
# Data for FUBT in 2023 saved in 0.53 seconds.
# Data for GALE in 2023 saved in 0.37 seconds.
# Data for GDKM in 2023 saved in 0.41 seconds.
# Data for GECK in 2023 saved in 0.40 seconds.
# Data for GECT in 2023 saved in 0.52 seconds.
# Data for GIMS in 2023 saved in 0.39 seconds.
# Data for GRDN in 2023 saved in 0.40 seconds.
# Data for GRNT in 2023 saved in 0.52 seconds.
# No data found for GRSN in 2023
# Data for GRZD in 2023 saved in 0.41 seconds.
# Data for GTC in 2023 saved in 0.52 seconds.
# Data for GTRG in 2023 saved in 0.40 seconds.
# Data for IJUG in 2023 saved in 0.27 seconds.
# Data for INB in 2023 saved in 0.40 seconds.
# Data for INHO in 2023 saved in 0.54 seconds.
# Data for INOV in 2023 saved in 0.41 seconds.
# Data for INPR in 2023 saved in 0.43 seconds.
# Data for INTP in 2023 saved in 0.66 seconds.
# No data found for JAKO in 2023
# No data found for JUSK in 2023
# Data for KARO in 2023 saved in 0.42 seconds.
# No data found for KDFO in 2023
# Data for KJUBI in 2023 saved in 0.58 seconds.
# Data for KKST in 2023 saved in 0.56 seconds.
# Data for KLST in 2023 saved in 0.55 seconds.
# Data for KMB in 2023 saved in 0.66 seconds.
# Data for KMPR in 2023 saved in 0.58 seconds.
# Data for KOMU in 2023 saved in 0.41 seconds.
# Data for KONF in 2023 saved in 0.44 seconds.
# Data for KONZ in 2023 saved in 0.52 seconds.
# No data found for KORZ in 2023
# Data for KPSS in 2023 saved in 0.44 seconds.
# No data found for KULT in 2023
# Data for KVAS in 2023 saved in 0.47 seconds.
# No data found for LAJO in 2023
# Data for LHND in 2023 saved in 0.33 seconds.
# Data for LOTO in 2023 saved in 0.40 seconds.
# Data for LOZP in 2023 saved in 0.40 seconds.
# No data found for MAGP in 2023
# Data for MAKP in 2023 saved in 0.53 seconds.
# Data for MAKS in 2023 saved in 0.39 seconds.
# Data for MB in 2023 saved in 0.40 seconds.
# Data for MERM in 2023 saved in 0.57 seconds.
# Data for MKSD in 2023 saved in 0.40 seconds.
# No data found for MLKR in 2023
# Data for MODA in 2023 saved in 0.59 seconds.
# Data for MPOL in 2023 saved in 0.40 seconds.
# Data for MPT in 2023 saved in 0.39 seconds.
# No data found for MPTE in 2023
# Data for MTUR in 2023 saved in 0.56 seconds.
# Data for MZHE in 2023 saved in 0.40 seconds.
# Data for MZPU in 2023 saved in 0.52 seconds.
# Data for NEME in 2023 saved in 0.68 seconds.
# Data for NOSK in 2023 saved in 0.57 seconds.
# No data found for OBPP in 2023
# Data for OILK in 2023 saved in 0.54 seconds.
# Data for OKTA in 2023 saved in 0.56 seconds.
# Data for OMOS in 2023 saved in 0.41 seconds.
# Data for OPFO in 2023 saved in 0.44 seconds.
# Data for OPTK in 2023 saved in 0.52 seconds.
# Data for ORAN in 2023 saved in 0.42 seconds.
# No data found for OSPO in 2023
# Data for OTEK in 2023 saved in 0.38 seconds.
# Data for PELK in 2023 saved in 0.46 seconds.
# No data found for PGGV in 2023
# Data for PKB in 2023 saved in 0.40 seconds.
# Data for POPK in 2023 saved in 0.41 seconds.
# Data for PPIV in 2023 saved in 0.51 seconds.
# Data for PROD in 2023 saved in 0.41 seconds.
# No data found for PROT in 2023
# Data for PTRS in 2023 saved in 0.37 seconds.
# Data for RADE in 2023 saved in 0.56 seconds.
# Data for REPL in 2023 saved in 0.43 seconds.
# Data for RIMI in 2023 saved in 0.40 seconds.
# Data for RINS in 2023 saved in 0.32 seconds.
# Data for RZEK in 2023 saved in 0.54 seconds.
# Data for RZIT in 2023 saved in 0.39 seconds.
# Data for RZIZ in 2023 saved in 0.40 seconds.
# Data for RZLE in 2023 saved in 0.56 seconds.
# Data for RZLV in 2023 saved in 0.39 seconds.
# Data for RZTK in 2023 saved in 0.54 seconds.
# Data for RZUG in 2023 saved in 0.65 seconds.
# Data for RZUS in 2023 saved in 0.54 seconds.
# Data for SBT in 2023 saved in 0.55 seconds.
# Data for SDOM in 2023 saved in 0.54 seconds.
# Data for SIL in 2023 saved in 0.39 seconds.
# No data found for SKON in 2023
# Data for SKP in 2023 saved in 0.38 seconds.
# Data for SLAV in 2023 saved in 0.51 seconds.
# Data for SNBT in 2023 saved in 0.41 seconds.
# Data for SNBTO in 2023 saved in 0.38 seconds.
# Data for SOLN in 2023 saved in 0.54 seconds.
# Data for SPAZ in 2023 saved in 0.41 seconds.
# Data for SPAZP in 2023 saved in 0.40 seconds.
# Data for SPOL in 2023 saved in 0.53 seconds.
# Data for SSPR in 2023 saved in 0.39 seconds.
# Data for STB in 2023 saved in 0.42 seconds.
# Data for STBP in 2023 saved in 0.53 seconds.
# Data for STIL in 2023 saved in 0.40 seconds.
# Data for STOK in 2023 saved in 0.42 seconds.
# Data for TAJM in 2023 saved in 0.56 seconds.
# No data found for TBKO in 2023
# Data for TEAL in 2023 saved in 0.40 seconds.
# Data for TEHN in 2023 saved in 0.40 seconds.
# Data for TEL in 2023 saved in 0.51 seconds.
# Data for TETE in 2023 saved in 0.38 seconds.
# Data for TIKV in 2023 saved in 0.41 seconds.
# Data for TKPR in 2023 saved in 0.63 seconds.
# Data for TKVS in 2023 saved in 0.52 seconds.
# Data for TNB in 2023 saved in 0.55 seconds.
# Data for TRDB in 2023 saved in 0.71 seconds.
# Data for TRPS in 2023 saved in 0.47 seconds.
# Data for TRUB in 2023 saved in 0.31 seconds.
# Data for TSMP in 2023 saved in 0.51 seconds.
# Data for TSZS in 2023 saved in 0.35 seconds.
# Data for TTK in 2023 saved in 0.39 seconds.
# Data for TTKO in 2023 saved in 0.39 seconds.
# Data for UNI in 2023 saved in 0.52 seconds.
# Data for USJE in 2023 saved in 0.38 seconds.
# Data for VARG in 2023 saved in 0.39 seconds.
# No data found for VFPM in 2023
# Data for VITA in 2023 saved in 0.39 seconds.
# Data for VROS in 2023 saved in 0.39 seconds.
# Data for VSC in 2023 saved in 0.33 seconds.
# Data for VTKS in 2023 saved in 0.53 seconds.
# Data for ZAS in 2023 saved in 0.49 seconds.
# Data for ZILU in 2023 saved in 0.49 seconds.
# Data for ZILUP in 2023 saved in 0.59 seconds.
# Data for ZIMS in 2023 saved in 0.36 seconds.
# Data for ZKAR in 2023 saved in 0.40 seconds.
# Data for ZPKO in 2023 saved in 0.50 seconds.
# Data for ZPOG in 2023 saved in 0.41 seconds.
# No data found for ZUAS in 2023
# Data for ADIN in 2022 saved in 0.39 seconds.
# Data for ALK in 2022 saved in 0.52 seconds.
# Data for ALKB in 2022 saved in 0.25 seconds.
# No data found for AMBR in 2022
# Data for AMEH in 2022 saved in 0.56 seconds.
# Data for APTK in 2022 saved in 0.65 seconds.
# Data for ATPP in 2022 saved in 0.54 seconds.
# Data for AUMK in 2022 saved in 0.52 seconds.
# Data for BANA in 2022 saved in 0.51 seconds.
# Data for BGOR in 2022 saved in 0.39 seconds.
# No data found for BIKF in 2022
# Data for BIM in 2022 saved in 0.39 seconds.
# Data for BLTU in 2022 saved in 0.54 seconds.
# Data for CBNG in 2022 saved in 0.40 seconds.
# Data for CDHV in 2022 saved in 0.33 seconds.
# Data for CEVI in 2022 saved in 0.55 seconds.
# Data for CKB in 2022 saved in 0.40 seconds.
# Data for CKBKO in 2022 saved in 0.38 seconds.
# Data for DEBA in 2022 saved in 0.51 seconds.
# Data for DIMI in 2022 saved in 0.40 seconds.
# Data for EDST in 2022 saved in 0.36 seconds.
# No data found for ELMA in 2022
# No data found for ELNC in 2022
# Data for ENER in 2022 saved in 0.26 seconds.
# No data found for ENSA in 2022
# Data for EUHA in 2022 saved in 0.39 seconds.
# Data for EUMK in 2022 saved in 0.32 seconds.
# Data for EVRO in 2022 saved in 0.40 seconds.
# Data for FAKM in 2022 saved in 0.52 seconds.
# Data for FERS in 2022 saved in 0.42 seconds.
# No data found for FKTL in 2022
# Data for FROT in 2022 saved in 0.41 seconds.
# Data for FUBT in 2022 saved in 0.53 seconds.
# Data for GALE in 2022 saved in 0.40 seconds.
# Data for GDKM in 2022 saved in 0.34 seconds.
# Data for GECK in 2022 saved in 0.67 seconds.
# Data for GECT in 2022 saved in 0.54 seconds.
# Data for GIMS in 2022 saved in 0.52 seconds.
# Data for GRDN in 2022 saved in 0.55 seconds.
# Data for GRNT in 2022 saved in 0.39 seconds.
# No data found for GRSN in 2022
# Data for GRZD in 2022 saved in 0.40 seconds.
# Data for GTC in 2022 saved in 0.52 seconds.
# Data for GTRG in 2022 saved in 0.40 seconds.
# Data for IJUG in 2022 saved in 0.38 seconds.
# Data for INB in 2022 saved in 0.54 seconds.
# Data for INHO in 2022 saved in 0.43 seconds.
# Data for INOV in 2022 saved in 0.24 seconds.
# Data for INPR in 2022 saved in 0.39 seconds.
# Data for INTP in 2022 saved in 0.51 seconds.
# No data found for JAKO in 2022
# No data found for JUSK in 2022
# Data for KARO in 2022 saved in 0.33 seconds.
# No data found for KDFO in 2022
# Data for KJUBI in 2022 saved in 0.51 seconds.
# No data found for KKST in 2022
# Data for KLST in 2022 saved in 0.38 seconds.
# Data for KMB in 2022 saved in 0.39 seconds.
# Data for KMPR in 2022 saved in 0.28 seconds.
# Data for KOMU in 2022 saved in 0.54 seconds.
# Data for KONF in 2022 saved in 0.39 seconds.
# Data for KONZ in 2022 saved in 0.38 seconds.
# No data found for KORZ in 2022
# Data for KPSS in 2022 saved in 0.55 seconds.
# No data found for KULT in 2022
# Data for KVAS in 2022 saved in 0.45 seconds.
# No data found for LAJO in 2022
# Data for LHND in 2022 saved in 0.67 seconds.
# Data for LOTO in 2022 saved in 0.61 seconds.
# Data for LOZP in 2022 saved in 1.54 seconds.
# No data found for MAGP in 2022
# Data for MAKP in 2022 saved in 0.67 seconds.
# Data for MAKS in 2022 saved in 0.40 seconds.
# Data for MB in 2022 saved in 0.40 seconds.
# Data for MERM in 2022 saved in 0.56 seconds.
# Data for MKSD in 2022 saved in 0.42 seconds.
# No data found for MLKR in 2022
# Data for MODA in 2022 saved in 0.41 seconds.
# Data for MPOL in 2022 saved in 0.57 seconds.
# Data for MPT in 2022 saved in 0.49 seconds.
# No data found for MPTE in 2022
# Data for MTUR in 2022 saved in 0.41 seconds.
# Data for MZHE in 2022 saved in 0.54 seconds.
# Data for MZPU in 2022 saved in 0.41 seconds.
# Data for NEME in 2022 saved in 0.40 seconds.
# Data for NOSK in 2022 saved in 0.57 seconds.
# No data found for OBPP in 2022
# Data for OILK in 2022 saved in 0.40 seconds.
# Data for OKTA in 2022 saved in 0.51 seconds.
# Data for OMOS in 2022 saved in 0.41 seconds.
# Data for OPFO in 2022 saved in 0.41 seconds.
# Data for OPTK in 2022 saved in 0.69 seconds.
# Data for ORAN in 2022 saved in 0.56 seconds.
# No data found for OSPO in 2022
# Data for OTEK in 2022 saved in 0.55 seconds.
# Data for PELK in 2022 saved in 0.56 seconds.
# No data found for PGGV in 2022
# Data for PKB in 2022 saved in 0.42 seconds.
# Data for POPK in 2022 saved in 0.41 seconds.
# Data for PPIV in 2022 saved in 1.63 seconds.
# Data for PROD in 2022 saved in 0.42 seconds.
# No data found for PROT in 2022
# No data found for PTRS in 2022
# Data for RADE in 2022 saved in 0.43 seconds.
# Data for REPL in 2022 saved in 0.53 seconds.
# Data for RIMI in 2022 saved in 0.40 seconds.
# No data found for RINS in 2022
# Data for RZEK in 2022 saved in 0.51 seconds.
# Data for RZIT in 2022 saved in 0.42 seconds.
# Data for RZIZ in 2022 saved in 0.37 seconds.
# Data for RZLE in 2022 saved in 0.39 seconds.
# Data for RZLV in 2022 saved in 0.65 seconds.
# Data for RZTK in 2022 saved in 0.39 seconds.
# Data for RZUG in 2022 saved in 0.40 seconds.
# Data for RZUS in 2022 saved in 0.54 seconds.
# Data for SBT in 2022 saved in 0.43 seconds.
# Data for SDOM in 2022 saved in 0.44 seconds.
# Data for SIL in 2022 saved in 0.76 seconds.
# Data for SKON in 2022 saved in 0.34 seconds.
# Data for SKP in 2022 saved in 0.54 seconds.
# Data for SLAV in 2022 saved in 0.52 seconds.
# Data for SNBT in 2022 saved in 0.49 seconds.
# Data for SNBTO in 2022 saved in 0.34 seconds.
# Data for SOLN in 2022 saved in 0.39 seconds.
# Data for SPAZ in 2022 saved in 0.52 seconds.
# Data for SPAZP in 2022 saved in 0.38 seconds.
# Data for SPOL in 2022 saved in 0.39 seconds.
# Data for SSPR in 2022 saved in 0.52 seconds.
# Data for STB in 2022 saved in 0.42 seconds.
# Data for STBP in 2022 saved in 0.50 seconds.
# Data for STIL in 2022 saved in 0.67 seconds.
# Data for STOK in 2022 saved in 0.48 seconds.
# Data for TAJM in 2022 saved in 0.48 seconds.
# Data for TBKO in 2022 saved in 1.28 seconds.
# Data for TEAL in 2022 saved in 0.44 seconds.
# Data for TEHN in 2022 saved in 0.46 seconds.
# Data for TEL in 2022 saved in 0.54 seconds.
# Data for TETE in 2022 saved in 0.40 seconds.
# Data for TIKV in 2022 saved in 0.39 seconds.
# Data for TKPR in 2022 saved in 0.52 seconds.
# Data for TKVS in 2022 saved in 0.52 seconds.
# Data for TNB in 2022 saved in 0.53 seconds.
# Data for TRDB in 2022 saved in 0.65 seconds.
# Data for TRPS in 2022 saved in 0.55 seconds.
# No data found for TRUB in 2022
# Data for TSMP in 2022 saved in 0.39 seconds.
# No data found for TSZS in 2022
# Data for TTK in 2022 saved in 0.57 seconds.
# Data for TTKO in 2022 saved in 0.40 seconds.
# Data for UNI in 2022 saved in 0.43 seconds.
# Data for USJE in 2022 saved in 0.61 seconds.
# Data for VARG in 2022 saved in 0.50 seconds.
# Data for VFPM in 2022 saved in 0.30 seconds.
# Data for VITA in 2022 saved in 0.44 seconds.
# Data for VROS in 2022 saved in 0.53 seconds.
# Data for VSC in 2022 saved in 0.41 seconds.
# Data for VTKS in 2022 saved in 0.41 seconds.
# Data for ZAS in 2022 saved in 0.52 seconds.
# Data for ZILU in 2022 saved in 0.40 seconds.
# Data for ZILUP in 2022 saved in 0.38 seconds.
# Data for ZIMS in 2022 saved in 0.56 seconds.
# Data for ZKAR in 2022 saved in 0.46 seconds.
# Data for ZPKO in 2022 saved in 0.48 seconds.
# Data for ZPOG in 2022 saved in 1.65 seconds.
# Data for ZUAS in 2022 saved in 1.57 seconds.
# Data for ADIN in 2021 saved in 1.20 seconds.
# Data for ALK in 2021 saved in 0.70 seconds.
# No data found for ALKB in 2021
# No data found for AMBR in 2021
# Data for AMEH in 2021 saved in 0.42 seconds.
# Data for APTK in 2021 saved in 0.53 seconds.
# Data for ATPP in 2021 saved in 0.36 seconds.
# Data for AUMK in 2021 saved in 0.42 seconds.
# Data for BANA in 2021 saved in 0.42 seconds.
# Data for BGOR in 2021 saved in 0.61 seconds.
# Data for BIKF in 2021 saved in 0.40 seconds.
# Data for BIM in 2021 saved in 0.41 seconds.
# Data for BLTU in 2021 saved in 0.54 seconds.
# Data for CBNG in 2021 saved in 0.38 seconds.
# No data found for CDHV in 2021
# Data for CEVI in 2021 saved in 0.41 seconds.
# Data for CKB in 2021 saved in 0.55 seconds.
# Data for CKBKO in 2021 saved in 0.41 seconds.
# Data for DEBA in 2021 saved in 0.39 seconds.
# Data for DIMI in 2021 saved in 0.53 seconds.
# No data found for EDST in 2021
# No data found for ELMA in 2021
# No data found for ELNC in 2021
# No data found for ENER in 2021
# No data found for ENSA in 2021
# Data for EUHA in 2021 saved in 0.41 seconds.
# No data found for EUMK in 2021
# Data for EVRO in 2021 saved in 0.53 seconds.
# Data for FAKM in 2021 saved in 0.61 seconds.
# Data for FERS in 2021 saved in 4.49 seconds.
# No data found for FKTL in 2021
# No data found for FROT in 2021
# Data for FUBT in 2021 saved in 5.23 seconds.
# Data for GALE in 2021 saved in 1.70 seconds.
# No data found for GDKM in 2021
# Data for GECK in 2021 saved in 2.19 seconds.
# Data for GECT in 2021 saved in 1.26 seconds.
# Data for GIMS in 2021 saved in 0.98 seconds.
# Data for GRDN in 2021 saved in 0.83 seconds.
# Data for GRNT in 2021 saved in 0.81 seconds.
# No data found for GRSN in 2021
# Data for GRZD in 2021 saved in 0.63 seconds.
# Data for GTC in 2021 saved in 0.91 seconds.
# Data for GTRG in 2021 saved in 0.64 seconds.
# Data for IJUG in 2021 saved in 2.43 seconds.
# Data for INB in 2021 saved in 1.51 seconds.
# Data for INHO in 2021 saved in 0.57 seconds.
# No data found for INOV in 2021
# Data for INPR in 2021 saved in 0.68 seconds.
# Data for INTP in 2021 saved in 0.82 seconds.
# No data found for JAKO in 2021
# Data for JUSK in 2021 saved in 0.72 seconds.
# Data for KARO in 2021 saved in 0.61 seconds.
# Data for KDFO in 2021 saved in 0.73 seconds.
# Data for KJUBI in 2021 saved in 0.64 seconds.
# No data found for KKST in 2021
# Data for KLST in 2021 saved in 0.65 seconds.
# Data for KMB in 2021 saved in 1.04 seconds.
# No data found for KMPR in 2021
# Data for KOMU in 2021 saved in 0.79 seconds.
# Data for KONF in 2021 saved in 0.96 seconds.
# Data for KONZ in 2021 saved in 0.80 seconds.
# No data found for KORZ in 2021
# Data for KPSS in 2021 saved in 0.66 seconds.
# No data found for KULT in 2021
# Data for KVAS in 2021 saved in 0.79 seconds.
# No data found for LAJO in 2021
# Data for LHND in 2021 saved in 0.57 seconds.
# Data for LOTO in 2021 saved in 0.65 seconds.
# Data for LOZP in 2021 saved in 0.72 seconds.
# No data found for MAGP in 2021
# Data for MAKP in 2021 saved in 0.60 seconds.
# Data for MAKS in 2021 saved in 0.62 seconds.
# Data for MB in 2021 saved in 2.18 seconds.
# Data for MERM in 2021 saved in 1.55 seconds.
# Data for MKSD in 2021 saved in 1.06 seconds.
# No data found for MLKR in 2021
# Data for MODA in 2021 saved in 1.12 seconds.
# Data for MPOL in 2021 saved in 0.89 seconds.
# Data for MPT in 2021 saved in 0.99 seconds.
# No data found for MPTE in 2021
# Data for MTUR in 2021 saved in 0.85 seconds.
# Data for MZHE in 2021 saved in 0.56 seconds.
# Data for MZPU in 2021 saved in 1.01 seconds.
# Data for NEME in 2021 saved in 0.79 seconds.
# Data for NOSK in 2021 saved in 0.63 seconds.
# No data found for OBPP in 2021
# Data for OILK in 2021 saved in 0.66 seconds.
# Data for OKTA in 2021 saved in 5.16 seconds.
# Data for OMOS in 2021 saved in 4.88 seconds.
# Data for OPFO in 2021 saved in 5.01 seconds.
# Data for OPTK in 2021 saved in 4.32 seconds.
# Data for ORAN in 2021 saved in 2.15 seconds.
# No data found for OSPO in 2021
# Data for OTEK in 2021 saved in 2.44 seconds.
# Data for PELK in 2021 saved in 1.83 seconds.
# No data found for PGGV in 2021
# Data for PKB in 2021 saved in 1.27 seconds.
# Data for POPK in 2021 saved in 1.12 seconds.
# Data for PPIV in 2021 saved in 1.37 seconds.
# No data found for PROD in 2021
# No data found for PROT in 2021
# No data found for PTRS in 2021
# Data for RADE in 2021 saved in 0.72 seconds.
# Data for REPL in 2021 saved in 0.83 seconds.
# Data for RIMI in 2021 saved in 0.59 seconds.
# No data found for RINS in 2021
# Data for RZEK in 2021 saved in 0.54 seconds.
# Data for RZIT in 2021 saved in 0.73 seconds.
# No data found for RZIZ in 2021
# Data for RZLE in 2021 saved in 0.42 seconds.
# Data for RZLV in 2021 saved in 0.41 seconds.
# Data for RZTK in 2021 saved in 0.61 seconds.
# Data for RZUG in 2021 saved in 0.43 seconds.
# Data for RZUS in 2021 saved in 0.43 seconds.
# Data for SBT in 2021 saved in 0.53 seconds.
# Data for SDOM in 2021 saved in 0.53 seconds.
# Data for SIL in 2021 saved in 0.53 seconds.
# No data found for SKON in 2021
# Data for SKP in 2021 saved in 0.32 seconds.
# Data for SLAV in 2021 saved in 0.57 seconds.
# No data found for SNBT in 2021
# No data found for SNBTO in 2021
# Data for SOLN in 2021 saved in 0.29 seconds.
# Data for SPAZ in 2021 saved in 0.56 seconds.
# Data for SPAZP in 2021 saved in 0.42 seconds.
# Data for SPOL in 2021 saved in 0.40 seconds.
# Data for SSPR in 2021 saved in 0.53 seconds.
# Data for STB in 2021 saved in 0.46 seconds.
# Data for STBP in 2021 saved in 0.42 seconds.
# Data for STIL in 2021 saved in 0.56 seconds.
# Data for STOK in 2021 saved in 0.41 seconds.
# Data for TAJM in 2021 saved in 0.39 seconds.
# Data for TBKO in 2021 saved in 0.27 seconds.
# Data for TEAL in 2021 saved in 0.52 seconds.
# Data for TEHN in 2021 saved in 0.43 seconds.
# Data for TEL in 2021 saved in 0.41 seconds.
# Data for TETE in 2021 saved in 0.55 seconds.
# Data for TIKV in 2021 saved in 0.41 seconds.
# Data for TKPR in 2021 saved in 0.41 seconds.
# Data for TKVS in 2021 saved in 0.51 seconds.
# Data for TNB in 2021 saved in 0.44 seconds.
# Data for TRDB in 2021 saved in 0.43 seconds.
# Data for TRPS in 2021 saved in 0.57 seconds.
# No data found for TRUB in 2021
# Data for TSMP in 2021 saved in 0.53 seconds.
# No data found for TSZS in 2021
# Data for TTK in 2021 saved in 0.72 seconds.
# Data for TTKO in 2021 saved in 0.60 seconds.
# Data for UNI in 2021 saved in 0.40 seconds.
# Data for USJE in 2021 saved in 0.56 seconds.
# Data for VARG in 2021 saved in 0.41 seconds.
# No data found for VFPM in 2021
# Data for VITA in 2021 saved in 0.41 seconds.
# Data for VROS in 2021 saved in 0.53 seconds.
# Data for VSC in 2021 saved in 0.38 seconds.
# Data for VTKS in 2021 saved in 0.39 seconds.
# Data for ZAS in 2021 saved in 0.54 seconds.
# Data for ZILU in 2021 saved in 0.41 seconds.
# Data for ZILUP in 2021 saved in 0.41 seconds.
# Data for ZIMS in 2021 saved in 0.54 seconds.
# Data for ZKAR in 2021 saved in 0.40 seconds.
# Data for ZPKO in 2021 saved in 0.40 seconds.
# Data for ZPOG in 2021 saved in 0.52 seconds.
# No data found for ZUAS in 2021
# Data for ADIN in 2020 saved in 0.42 seconds.
# Data for ALK in 2020 saved in 0.39 seconds.
# Data for ALKB in 2020 saved in 0.57 seconds.
# No data found for AMBR in 2020
# Data for AMEH in 2020 saved in 0.40 seconds.
# Data for APTK in 2020 saved in 0.41 seconds.
# Data for ATPP in 2020 saved in 0.22 seconds.
# Data for AUMK in 2020 saved in 0.57 seconds.
# Data for BANA in 2020 saved in 0.52 seconds.
# Data for BGOR in 2020 saved in 0.61 seconds.
# Data for BIKF in 2020 saved in 0.71 seconds.
# Data for BIM in 2020 saved in 0.55 seconds.
# Data for BLTU in 2020 saved in 0.48 seconds.
# Data for CBNG in 2020 saved in 0.53 seconds.
# Data for CDHV in 2020 saved in 0.20 seconds.
# Data for CEVI in 2020 saved in 0.40 seconds.
# Data for CKB in 2020 saved in 0.41 seconds.
# Data for CKBKO in 2020 saved in 0.61 seconds.
# Data for DEBA in 2020 saved in 0.40 seconds.
# Data for DIMI in 2020 saved in 0.41 seconds.
# No data found for EDST in 2020
# Data for ELMA in 2020 saved in 0.23 seconds.
# Data for ELNC in 2020 saved in 0.23 seconds.
# No data found for ENER in 2020
# No data found for ENSA in 2020
# Data for EUHA in 2020 saved in 0.38 seconds.
# No data found for EUMK in 2020
# Data for EVRO in 2020 saved in 0.53 seconds.
# Data for FAKM in 2020 saved in 0.42 seconds.
# Data for FERS in 2020 saved in 0.42 seconds.
# No data found for FKTL in 2020
# Data for FROT in 2020 saved in 0.62 seconds.
# Data for FUBT in 2020 saved in 0.39 seconds.
# Data for GALE in 2020 saved in 0.31 seconds.
# No data found for GDKM in 2020
# Data for GECK in 2020 saved in 0.55 seconds.
# Data for GECT in 2020 saved in 0.42 seconds.
# Data for GIMS in 2020 saved in 0.22 seconds.
# Data for GRDN in 2020 saved in 0.22 seconds.
# Data for GRNT in 2020 saved in 0.39 seconds.
# Data for GRSN in 2020 saved in 0.44 seconds.
# Data for GRZD in 2020 saved in 0.52 seconds.
# Data for GTC in 2020 saved in 0.52 seconds.
# Data for GTRG in 2020 saved in 0.52 seconds.
# No data found for IJUG in 2020
# Data for INB in 2020 saved in 0.39 seconds.
# Data for INHO in 2020 saved in 0.42 seconds.
# No data found for INOV in 2020
# Data for INPR in 2020 saved in 0.52 seconds.
# Data for INTP in 2020 saved in 0.44 seconds.
# No data found for JAKO in 2020
# Data for JUSK in 2020 saved in 0.37 seconds.
# Data for KARO in 2020 saved in 0.49 seconds.
# Data for KDFO in 2020 saved in 0.36 seconds.
# Data for KJUBI in 2020 saved in 0.42 seconds.
# No data found for KKST in 2020
# Data for KLST in 2020 saved in 0.51 seconds.
# Data for KMB in 2020 saved in 0.45 seconds.
# Data for KMPR in 2020 saved in 0.20 seconds.
# Data for KOMU in 2020 saved in 0.39 seconds.
# Data for KONF in 2020 saved in 0.59 seconds.
# Data for KONZ in 2020 saved in 0.42 seconds.
# No data found for KORZ in 2020
# Data for KPSS in 2020 saved in 0.41 seconds.
# No data found for KULT in 2020
# Data for KVAS in 2020 saved in 0.58 seconds.
# No data found for LAJO in 2020
# Data for LHND in 2020 saved in 0.37 seconds.
# Data for LOTO in 2020 saved in 0.41 seconds.
# Data for LOZP in 2020 saved in 0.53 seconds.
# Data for MAGP in 2020 saved in 0.20 seconds.
# Data for MAKP in 2020 saved in 0.48 seconds.
# Data for MAKS in 2020 saved in 0.73 seconds.
# Data for MB in 2020 saved in 0.52 seconds.
# Data for MERM in 2020 saved in 0.57 seconds.
# Data for MKSD in 2020 saved in 0.62 seconds.
# No data found for MLKR in 2020
# Data for MODA in 2020 saved in 0.41 seconds.
# Data for MPOL in 2020 saved in 0.41 seconds.
# Data for MPT in 2020 saved in 0.55 seconds.
# No data found for MPTE in 2020
# Data for MTUR in 2020 saved in 0.43 seconds.
# Data for MZHE in 2020 saved in 0.41 seconds.
# Data for MZPU in 2020 saved in 0.52 seconds.
# Data for NEME in 2020 saved in 0.40 seconds.
# Data for NOSK in 2020 saved in 0.39 seconds.
# No data found for OBPP in 2020
# Data for OILK in 2020 saved in 0.54 seconds.
# Data for OKTA in 2020 saved in 0.41 seconds.
# No data found for OMOS in 2020
# No data found for OPFO in 2020
# Data for OPTK in 2020 saved in 0.54 seconds.
# Data for ORAN in 2020 saved in 0.38 seconds.
# No data found for OSPO in 2020
# Data for OTEK in 2020 saved in 0.39 seconds.
# Data for PELK in 2020 saved in 0.27 seconds.
# Data for PGGV in 2020 saved in 0.36 seconds.
# Data for PKB in 2020 saved in 0.40 seconds.
# Data for POPK in 2020 saved in 0.39 seconds.
# Data for PPIV in 2020 saved in 0.48 seconds.
# Data for PROD in 2020 saved in 0.41 seconds.
# No data found for PROT in 2020
# Data for PTRS in 2020 saved in 0.46 seconds.
# Data for RADE in 2020 saved in 0.71 seconds.
# Data for REPL in 2020 saved in 0.58 seconds.
# Data for RIMI in 2020 saved in 0.30 seconds.
# No data found for RINS in 2020
# Data for RZEK in 2020 saved in 0.49 seconds.
# Data for RZIT in 2020 saved in 0.53 seconds.
# Data for RZIZ in 2020 saved in 0.40 seconds.
# Data for RZLE in 2020 saved in 0.39 seconds.
# Data for RZLV in 2020 saved in 0.54 seconds.
# Data for RZTK in 2020 saved in 0.39 seconds.
# Data for RZUG in 2020 saved in 0.39 seconds.
# Data for RZUS in 2020 saved in 0.52 seconds.
# Data for SBT in 2020 saved in 0.40 seconds.
# Data for SDOM in 2020 saved in 0.39 seconds.
# Data for SIL in 2020 saved in 0.51 seconds.
# No data found for SKON in 2020
# Data for SKP in 2020 saved in 0.40 seconds.
# Data for SLAV in 2020 saved in 0.39 seconds.
# Data for SNBT in 2020 saved in 0.33 seconds.
# No data found for SNBTO in 2020
# Data for SOLN in 2020 saved in 0.38 seconds.
# Data for SPAZ in 2020 saved in 0.42 seconds.
# Data for SPAZP in 2020 saved in 0.52 seconds.
# Data for SPOL in 2020 saved in 0.40 seconds.
# Data for SSPR in 2020 saved in 0.41 seconds.
# Data for STB in 2020 saved in 0.55 seconds.
# Data for STBP in 2020 saved in 0.40 seconds.
# Data for STIL in 2020 saved in 0.39 seconds.
# Data for STOK in 2020 saved in 0.64 seconds.
# Data for TAJM in 2020 saved in 0.50 seconds.
# No data found for TBKO in 2020
# Data for TEAL in 2020 saved in 0.53 seconds.
# Data for TEHN in 2020 saved in 0.73 seconds.
# Data for TEL in 2020 saved in 0.39 seconds.
# Data for TETE in 2020 saved in 0.45 seconds.
# Data for TIKV in 2020 saved in 0.54 seconds.
# Data for TKPR in 2020 saved in 0.42 seconds.
# Data for TKVS in 2020 saved in 0.40 seconds.
# Data for TNB in 2020 saved in 0.55 seconds.
# Data for TRDB in 2020 saved in 0.38 seconds.
# Data for TRPS in 2020 saved in 0.39 seconds.
# Data for TRUB in 2020 saved in 0.51 seconds.
# Data for TSMP in 2020 saved in 0.39 seconds.
# No data found for TSZS in 2020
# Data for TTK in 2020 saved in 0.40 seconds.
# Data for TTKO in 2020 saved in 0.50 seconds.
# Data for UNI in 2020 saved in 0.41 seconds.
# Data for USJE in 2020 saved in 0.39 seconds.
# Data for VARG in 2020 saved in 0.57 seconds.
# No data found for VFPM in 2020
# Data for VITA in 2020 saved in 0.42 seconds.
# Data for VROS in 2020 saved in 0.41 seconds.
# Data for VSC in 2020 saved in 0.21 seconds.
# Data for VTKS in 2020 saved in 0.56 seconds.
# Data for ZAS in 2020 saved in 0.46 seconds.
# Data for ZILU in 2020 saved in 0.57 seconds.
# Data for ZILUP in 2020 saved in 0.64 seconds.
# Data for ZIMS in 2020 saved in 0.24 seconds.
# Data for ZKAR in 2020 saved in 0.53 seconds.
# Data for ZPKO in 2020 saved in 0.41 seconds.
# Data for ZPOG in 2020 saved in 0.53 seconds.
# Data for ZUAS in 2020 saved in 0.20 seconds.
# Data for ADIN in 2019 saved in 0.41 seconds.
# Data for ALK in 2019 saved in 0.51 seconds.
# Data for ALKB in 2019 saved in 0.39 seconds.
# No data found for AMBR in 2019
# Data for AMEH in 2019 saved in 0.39 seconds.
# Data for APTK in 2019 saved in 0.54 seconds.
# Data for ATPP in 2019 saved in 0.38 seconds.
# Data for AUMK in 2019 saved in 0.42 seconds.
# Data for BANA in 2019 saved in 0.53 seconds.
# Data for BGOR in 2019 saved in 0.45 seconds.
# Data for BIKF in 2019 saved in 0.31 seconds.
# Data for BIM in 2019 saved in 0.52 seconds.
# Data for BLTU in 2019 saved in 0.39 seconds.
# Data for CBNG in 2019 saved in 0.29 seconds.
# Data for CDHV in 2019 saved in 0.40 seconds.
# Data for CEVI in 2019 saved in 0.54 seconds.
# Data for CKB in 2019 saved in 0.39 seconds.
# Data for CKBKO in 2019 saved in 0.29 seconds.
# Data for DEBA in 2019 saved in 0.41 seconds.
# Data for DIMI in 2019 saved in 0.54 seconds.
# No data found for EDST in 2019
# Data for ELMA in 2019 saved in 0.41 seconds.
# No data found for ELNC in 2019
# No data found for ENER in 2019
# No data found for ENSA in 2019
# Data for EUHA in 2019 saved in 0.69 seconds.
# No data found for EUMK in 2019
# Data for EVRO in 2019 saved in 0.56 seconds.
# Data for FAKM in 2019 saved in 0.46 seconds.
# Data for FERS in 2019 saved in 0.55 seconds.
# No data found for FKTL in 2019
# Data for FROT in 2019 saved in 0.39 seconds.
# Data for FUBT in 2019 saved in 0.57 seconds.
# No data found for GALE in 2019
# No data found for GDKM in 2019
# Data for GECK in 2019 saved in 0.40 seconds.
# Data for GECT in 2019 saved in 0.40 seconds.
# Data for GIMS in 2019 saved in 0.53 seconds.
# Data for GRDN in 2019 saved in 0.43 seconds.
# Data for GRNT in 2019 saved in 0.40 seconds.
# Data for GRSN in 2019 saved in 0.49 seconds.
# Data for GRZD in 2019 saved in 0.39 seconds.
# Data for GTC in 2019 saved in 0.41 seconds.
# Data for GTRG in 2019 saved in 0.52 seconds.
# No data found for IJUG in 2019
# Data for INB in 2019 saved in 0.41 seconds.
# Data for INHO in 2019 saved in 0.39 seconds.
# No data found for INOV in 2019
# Data for INPR in 2019 saved in 0.53 seconds.
# Data for INTP in 2019 saved in 0.40 seconds.
# No data found for JAKO in 2019
# No data found for JUSK in 2019
# Data for KARO in 2019 saved in 0.52 seconds.
# Data for KDFO in 2019 saved in 0.41 seconds.
# Data for KJUBI in 2019 saved in 0.52 seconds.
# No data found for KKST in 2019
# Data for KLST in 2019 saved in 0.70 seconds.
# Data for KMB in 2019 saved in 0.57 seconds.
# Data for KMPR in 2019 saved in 0.55 seconds.
# Data for KOMU in 2019 saved in 0.57 seconds.
# Data for KONF in 2019 saved in 0.40 seconds.
# Data for KONZ in 2019 saved in 0.40 seconds.
# No data found for KORZ in 2019
# Data for KPSS in 2019 saved in 0.54 seconds.
# No data found for KULT in 2019
# Data for KVAS in 2019 saved in 0.42 seconds.
# No data found for LAJO in 2019
# No data found for LHND in 2019
# Data for LOTO in 2019 saved in 0.55 seconds.
# Data for LOZP in 2019 saved in 0.39 seconds.
# Data for MAGP in 2019 saved in 0.39 seconds.
# Data for MAKP in 2019 saved in 0.52 seconds.
# Data for MAKS in 2019 saved in 0.40 seconds.
# Data for MB in 2019 saved in 0.40 seconds.
# Data for MERM in 2019 saved in 0.52 seconds.
# Data for MKSD in 2019 saved in 0.41 seconds.
# No data found for MLKR in 2019
# Data for MODA in 2019 saved in 0.39 seconds.
# Data for MPOL in 2019 saved in 0.54 seconds.
# Data for MPT in 2019 saved in 0.40 seconds.
# No data found for MPTE in 2019
# Data for MTUR in 2019 saved in 0.42 seconds.
# Data for MZHE in 2019 saved in 0.54 seconds.
# Data for MZPU in 2019 saved in 0.40 seconds.
# Data for NEME in 2019 saved in 0.49 seconds.
# Data for NOSK in 2019 saved in 0.70 seconds.
# No data found for OBPP in 2019
# Data for OILK in 2019 saved in 0.54 seconds.
# Data for OKTA in 2019 saved in 0.54 seconds.
# No data found for OMOS in 2019
# No data found for OPFO in 2019
# Data for OPTK in 2019 saved in 0.39 seconds.
# Data for ORAN in 2019 saved in 0.39 seconds.
# No data found for OSPO in 2019
# Data for OTEK in 2019 saved in 0.52 seconds.
# No data found for PELK in 2019
# Data for PGGV in 2019 saved in 0.42 seconds.
# Data for PKB in 2019 saved in 0.40 seconds.
# Data for POPK in 2019 saved in 0.55 seconds.
# Data for PPIV in 2019 saved in 0.43 seconds.
# Data for PROD in 2019 saved in 0.42 seconds.
# No data found for PROT in 2019
# Data for PTRS in 2019 saved in 0.63 seconds.
# Data for RADE in 2019 saved in 0.41 seconds.
# Data for REPL in 2019 saved in 0.41 seconds.
# No data found for RIMI in 2019
# No data found for RINS in 2019
# Data for RZEK in 2019 saved in 0.41 seconds.
# Data for RZIT in 2019 saved in 0.42 seconds.
# Data for RZIZ in 2019 saved in 0.51 seconds.
# Data for RZLE in 2019 saved in 0.39 seconds.
# Data for RZLV in 2019 saved in 0.40 seconds.
# Data for RZTK in 2019 saved in 0.51 seconds.
# Data for RZUG in 2019 saved in 0.41 seconds.
# Data for RZUS in 2019 saved in 0.43 seconds.
# Data for SBT in 2019 saved in 0.69 seconds.
# Data for SDOM in 2019 saved in 0.56 seconds.
# Data for SIL in 2019 saved in 0.54 seconds.
# No data found for SKON in 2019
# Data for SKP in 2019 saved in 0.55 seconds.
# Data for SLAV in 2019 saved in 0.45 seconds.
# Data for SNBT in 2019 saved in 0.40 seconds.
# No data found for SNBTO in 2019
# Data for SOLN in 2019 saved in 0.55 seconds.
# Data for SPAZ in 2019 saved in 0.40 seconds.
# Data for SPAZP in 2019 saved in 0.40 seconds.
# Data for SPOL in 2019 saved in 0.53 seconds.
# Data for SSPR in 2019 saved in 0.41 seconds.
# Data for STB in 2019 saved in 0.42 seconds.
# Data for STBP in 2019 saved in 0.55 seconds.
# Data for STIL in 2019 saved in 0.44 seconds.
# Data for STOK in 2019 saved in 0.41 seconds.
# Data for TAJM in 2019 saved in 0.54 seconds.
# No data found for TBKO in 2019
# Data for TEAL in 2019 saved in 0.44 seconds.
# Data for TEHN in 2019 saved in 0.40 seconds.
# Data for TEL in 2019 saved in 0.62 seconds.
# Data for TETE in 2019 saved in 0.41 seconds.
# Data for TIKV in 2019 saved in 0.43 seconds.
# Data for TKPR in 2019 saved in 0.53 seconds.
# Data for TKVS in 2019 saved in 0.40 seconds.
# Data for TNB in 2019 saved in 0.43 seconds.
# Data for TRDB in 2019 saved in 0.72 seconds.
# Data for TRPS in 2019 saved in 0.55 seconds.
# No data found for TRUB in 2019
# Data for TSMP in 2019 saved in 0.58 seconds.
# No data found for TSZS in 2019
# Data for TTK in 2019 saved in 0.56 seconds.
# Data for TTKO in 2019 saved in 0.24 seconds.
# Data for UNI in 2019 saved in 0.40 seconds.
# Data for USJE in 2019 saved in 0.53 seconds.
# Data for VARG in 2019 saved in 0.32 seconds.
# No data found for VFPM in 2019
# Data for VITA in 2019 saved in 0.40 seconds.
# Data for VROS in 2019 saved in 0.52 seconds.
# Data for VSC in 2019 saved in 0.42 seconds.
# Data for VTKS in 2019 saved in 0.39 seconds.
# Data for ZAS in 2019 saved in 0.55 seconds.
# Data for ZILU in 2019 saved in 0.39 seconds.
# Data for ZILUP in 2019 saved in 0.41 seconds.
# Data for ZIMS in 2019 saved in 0.35 seconds.
# Data for ZKAR in 2019 saved in 0.53 seconds.
# Data for ZPKO in 2019 saved in 0.38 seconds.
# Data for ZPOG in 2019 saved in 0.38 seconds.
# Data for ZUAS in 2019 saved in 0.52 seconds.
# Data for ADIN in 2018 saved in 0.40 seconds.
# Data for ALK in 2018 saved in 0.40 seconds.
# Data for ALKB in 2018 saved in 0.53 seconds.
# No data found for AMBR in 2018
# Data for AMEH in 2018 saved in 0.43 seconds.
# Data for APTK in 2018 saved in 0.59 seconds.
# Data for ATPP in 2018 saved in 0.63 seconds.
# Data for AUMK in 2018 saved in 0.54 seconds.
# Data for BANA in 2018 saved in 0.71 seconds.
# Data for BGOR in 2018 saved in 0.60 seconds.
# Data for BIKF in 2018 saved in 0.45 seconds.
# Data for BIM in 2018 saved in 0.42 seconds.
# Data for BLTU in 2018 saved in 0.55 seconds.
# No data found for CBNG in 2018
# Data for CDHV in 2018 saved in 0.41 seconds.
# Data for CEVI in 2018 saved in 0.57 seconds.
# Data for CKB in 2018 saved in 0.40 seconds.
# No data found for CKBKO in 2018
# Data for DEBA in 2018 saved in 0.42 seconds.
# Data for DIMI in 2018 saved in 0.53 seconds.
# Data for EDST in 2018 saved in 0.20 seconds.
# Data for ELMA in 2018 saved in 0.32 seconds.
# No data found for ELNC in 2018
# Data for ENER in 2018 saved in 0.39 seconds.
# No data found for ENSA in 2018
# Data for EUHA in 2018 saved in 0.53 seconds.
# Data for EUMK in 2018 saved in 0.41 seconds.
# Data for EVRO in 2018 saved in 0.40 seconds.
# Data for FAKM in 2018 saved in 0.54 seconds.
# Data for FERS in 2018 saved in 0.39 seconds.
# No data found for FKTL in 2018
# Data for FROT in 2018 saved in 0.25 seconds.
# Data for FUBT in 2018 saved in 0.55 seconds.
# Data for GALE in 2018 saved in 0.41 seconds.
# Data for GDKM in 2018 saved in 0.40 seconds.
# Data for GECK in 2018 saved in 0.50 seconds.
# Data for GECT in 2018 saved in 0.52 seconds.
# Data for GIMS in 2018 saved in 0.40 seconds.
# Data for GRDN in 2018 saved in 0.43 seconds.
# Data for GRNT in 2018 saved in 0.76 seconds.
# Data for GRSN in 2018 saved in 0.49 seconds.
# Data for GRZD in 2018 saved in 0.40 seconds.
# Data for GTC in 2018 saved in 0.54 seconds.
# Data for GTRG in 2018 saved in 0.39 seconds.
# Data for IJUG in 2018 saved in 0.38 seconds.
# Data for INB in 2018 saved in 0.55 seconds.
# Data for INHO in 2018 saved in 0.40 seconds.
# No data found for INOV in 2018
# Data for INPR in 2018 saved in 0.42 seconds.
# Data for INTP in 2018 saved in 0.51 seconds.
# No data found for JAKO in 2018
# No data found for JUSK in 2018
# Data for KARO in 2018 saved in 0.41 seconds.
# Data for KDFO in 2018 saved in 0.60 seconds.
# Data for KJUBI in 2018 saved in 0.38 seconds.
# No data found for KKST in 2018
# Data for KLST in 2018 saved in 0.41 seconds.
# Data for KMB in 2018 saved in 0.57 seconds.
# Data for KMPR in 2018 saved in 0.28 seconds.
# Data for KOMU in 2018 saved in 0.40 seconds.
# Data for KONF in 2018 saved in 0.39 seconds.
# Data for KONZ in 2018 saved in 0.55 seconds.
# No data found for KORZ in 2018
# Data for KPSS in 2018 saved in 0.40 seconds.
# No data found for KULT in 2018
# Data for KVAS in 2018 saved in 0.53 seconds.
# No data found for LAJO in 2018
# No data found for LHND in 2018
# Data for LOTO in 2018 saved in 0.53 seconds.
# Data for LOZP in 2018 saved in 0.54 seconds.
# Data for MAGP in 2018 saved in 0.53 seconds.
# Data for MAKP in 2018 saved in 0.43 seconds.
# Data for MAKS in 2018 saved in 0.38 seconds.
# Data for MB in 2018 saved in 0.53 seconds.
# Data for MERM in 2018 saved in 0.39 seconds.
# Data for MKSD in 2018 saved in 0.40 seconds.
# No data found for MLKR in 2018
# Data for MODA in 2018 saved in 0.56 seconds.
# Data for MPOL in 2018 saved in 0.43 seconds.
# Data for MPT in 2018 saved in 0.41 seconds.
# No data found for MPTE in 2018
# Data for MTUR in 2018 saved in 0.54 seconds.
# Data for MZHE in 2018 saved in 0.41 seconds.
# Data for MZPU in 2018 saved in 0.43 seconds.
# Data for NEME in 2018 saved in 0.54 seconds.
# Data for NOSK in 2018 saved in 0.46 seconds.
# No data found for OBPP in 2018
# Data for OILK in 2018 saved in 0.40 seconds.
# Data for OKTA in 2018 saved in 0.56 seconds.
# No data found for OMOS in 2018
# No data found for OPFO in 2018
# Data for OPTK in 2018 saved in 0.29 seconds.
# Data for ORAN in 2018 saved in 0.49 seconds.
# No data found for OSPO in 2018
# Data for OTEK in 2018 saved in 0.41 seconds.
# Data for PELK in 2018 saved in 0.23 seconds.
# Data for PGGV in 2018 saved in 0.39 seconds.
# Data for PKB in 2018 saved in 0.70 seconds.
# Data for POPK in 2018 saved in 0.58 seconds.
# Data for PPIV in 2018 saved in 0.55 seconds.
# Data for PROD in 2018 saved in 0.69 seconds.
# No data found for PROT in 2018
# ...
# Data for SOLN in 2017 saved in 0.40 seconds.
# Data for SPAZ in 2017 saved in 0.55 seconds.
# Data for SPAZP in 2017 saved in 0.43 seconds.
# Data for SPOL in 2017 saved in 0.39 seconds.
# Data for SSPR in 2017 saved in 0.53 seconds.
# Data for STB in 2017 saved in 0.42 seconds.
# Data for STBP in 2017 saved in 0.41 seconds.
# Data for STIL in 2017 saved in 0.54 seconds.
# Data for STOK in 2017 saved in 0.42 seconds.
# Data for TAJM in 2017 saved in 0.39 seconds.
# Data for TBKO in 2017 saved in 0.45 seconds.
# Data for TEAL in 2017 saved in 0.40 seconds.
# Data for TEHN in 2017 saved in 0.39 seconds.
# Data for TEL in 2017 saved in 0.43 seconds.
# Data for TETE in 2017 saved in 0.54 seconds.
# Data for TIKV in 2017 saved in 0.42 seconds.
# Data for TKPR in 2017 saved in 0.42 seconds.
# Data for TKVS in 2017 saved in 0.52 seconds.
# Data for TNB in 2017 saved in 0.40 seconds.
# Data for TRDB in 2017 saved in 0.43 seconds.
# Data for TRPS in 2017 saved in 0.59 seconds.
# Data for TRUB in 2017 saved in 0.58 seconds.
# Data for TSMP in 2017 saved in 0.51 seconds.
# No data found for TSZS in 2017
# Data for TTK in 2017 saved in 0.56 seconds.
# No data found for TTKO in 2017
# Data for UNI in 2017 saved in 0.39 seconds.
# Data for USJE in 2017 saved in 0.51 seconds.
# No data found for VARG in 2017
# No data found for VFPM in 2017
# Data for VITA in 2017 saved in 0.42 seconds.
# Data for VROS in 2017 saved in 0.41 seconds.
# No data found for VSC in 2017
# Data for VTKS in 2017 saved in 0.55 seconds.
# Data for ZAS in 2017 saved in 0.41 seconds.
# Data for ZILU in 2017 saved in 0.40 seconds.
# Data for ZILUP in 2017 saved in 0.56 seconds.
# Data for ZIMS in 2017 saved in 0.37 seconds.
# Data for ZKAR in 2017 saved in 0.42 seconds.
# Data for ZPKO in 2017 saved in 0.60 seconds.
# Data for ZPOG in 2017 saved in 0.44 seconds.
# Data for ZUAS in 2017 saved in 0.31 seconds.
# Data for ADIN in 2016 saved in 0.60 seconds.
# Data for ALK in 2016 saved in 0.50 seconds.
# Data for ALKB in 2016 saved in 0.25 seconds.
# No data found for AMBR in 2016
# Data for AMEH in 2016 saved in 0.41 seconds.
# Data for APTK in 2016 saved in 0.56 seconds.
# Data for ATPP in 2016 saved in 0.41 seconds.
# Data for AUMK in 2016 saved in 0.41 seconds.
# Data for BANA in 2016 saved in 0.68 seconds.
# Data for BGOR in 2016 saved in 0.53 seconds.
# No data found for BIKF in 2016
# Data for BIM in 2016 saved in 0.54 seconds.
# Data for BLTU in 2016 saved in 0.61 seconds.
# No data found for CBNG in 2016
# Data for CDHV in 2016 saved in 0.49 seconds.
# Data for CEVI in 2016 saved in 0.50 seconds.
# Data for CKB in 2016 saved in 0.42 seconds.
# No data found for CKBKO in 2016
# Data for DEBA in 2016 saved in 0.39 seconds.
# Data for DIMI in 2016 saved in 0.59 seconds.
# No data found for EDST in 2016
# Data for ELMA in 2016 saved in 0.40 seconds.
# No data found for ELNC in 2016
# Data for ENER in 2016 saved in 0.24 seconds.
# No data found for ENSA in 2016
# Data for EUHA in 2016 saved in 0.54 seconds.
# Data for EUMK in 2016 saved in 0.38 seconds.
# Data for EVRO in 2016 saved in 0.39 seconds.
# Data for FAKM in 2016 saved in 0.53 seconds.
# Data for FERS in 2016 saved in 0.40 seconds.
# No data found for FKTL in 2016
# No data found for FROT in 2016
# Data for FUBT in 2016 saved in 0.41 seconds.
# Data for GALE in 2016 saved in 0.58 seconds.
# No data found for GDKM in 2016
# Data for GECK in 2016 saved in 0.47 seconds.
# Data for GECT in 2016 saved in 0.40 seconds.
# Data for GIMS in 2016 saved in 0.52 seconds.
# No data found for GRDN in 2016
# Data for GRNT in 2016 saved in 0.53 seconds.
# Data for GRSN in 2016 saved in 0.54 seconds.
# Data for GRZD in 2016 saved in 0.66 seconds.
# Data for GTC in 2016 saved in 0.55 seconds.
# Data for GTRG in 2016 saved in 0.44 seconds.
# Data for IJUG in 2016 saved in 0.37 seconds.
# Data for INB in 2016 saved in 0.39 seconds.
# Data for INHO in 2016 saved in 0.40 seconds.
# No data found for INOV in 2016
# Data for INPR in 2016 saved in 0.53 seconds.
# Data for INTP in 2016 saved in 0.42 seconds.
# No data found for JAKO in 2016
# Data for JUSK in 2016 saved in 0.34 seconds.
# Data for KARO in 2016 saved in 0.58 seconds.
# No data found for KDFO in 2016
# Data for KJUBI in 2016 saved in 0.41 seconds.
# No data found for KKST in 2016
# Data for KLST in 2016 saved in 0.39 seconds.
# Data for KMB in 2016 saved in 0.58 seconds.
# Data for KMPR in 2016 saved in 0.42 seconds.
# Data for KOMU in 2016 saved in 0.39 seconds.
# Data for KONF in 2016 saved in 0.58 seconds.
# Data for KONZ in 2016 saved in 0.41 seconds.
# Data for KORZ in 2016 saved in 0.39 seconds.
# Data for KPSS in 2016 saved in 0.51 seconds.
# No data found for KULT in 2016
# Data for KVAS in 2016 saved in 0.39 seconds.
# No data found for LAJO in 2016
# No data found for LHND in 2016
# Data for LOTO in 2016 saved in 0.52 seconds.
# Data for LOZP in 2016 saved in 0.43 seconds.
# No data found for MAGP in 2016
# Data for MAKP in 2016 saved in 0.54 seconds.
# Data for MAKS in 2016 saved in 0.72 seconds.
# Data for MB in 2016 saved in 0.54 seconds.
# Data for MERM in 2016 saved in 0.43 seconds.
# Data for MKSD in 2016 saved in 0.55 seconds.
# No data found for MLKR in 2016
# Data for MODA in 2016 saved in 0.43 seconds.
# Data for MPOL in 2016 saved in 0.40 seconds.
# Data for MPT in 2016 saved in 0.54 seconds.
# No data found for MPTE in 2016
# Data for MTUR in 2016 saved in 0.39 seconds.
# Data for MZHE in 2016 saved in 0.41 seconds.
# Data for MZPU in 2016 saved in 0.53 seconds.
# Data for NEME in 2016 saved in 0.41 seconds.
# Data for NOSK in 2016 saved in 0.39 seconds.
# Data for OBPP in 2016 saved in 0.42 seconds.
# Data for OILK in 2016 saved in 0.43 seconds.
# Data for OKTA in 2016 saved in 0.42 seconds.
# No data found for OMOS in 2016
# No data found for OPFO in 2016
# Data for OPTK in 2016 saved in 0.53 seconds.
# Data for ORAN in 2016 saved in 0.39 seconds.
# No data found for OSPO in 2016
# Data for OTEK in 2016 saved in 0.39 seconds.
# Data for PELK in 2016 saved in 0.54 seconds.
# Data for PGGV in 2016 saved in 0.38 seconds.
# Data for PKB in 2016 saved in 0.38 seconds.
# Data for POPK in 2016 saved in 0.50 seconds.
# Data for PPIV in 2016 saved in 0.42 seconds.
# Data for PROD in 2016 saved in 0.52 seconds.
# No data found for PROT in 2016
# No data found for PTRS in 2016
# Data for RADE in 2016 saved in 0.54 seconds.
# Data for REPL in 2016 saved in 0.52 seconds.
# Data for RIMI in 2016 saved in 0.48 seconds.
# Data for RINS in 2016 saved in 0.40 seconds.
# Data for RZEK in 2016 saved in 0.45 seconds.
# Data for RZIT in 2016 saved in 0.40 seconds.
# Data for RZIZ in 2016 saved in 0.54 seconds.
# Data for RZLE in 2016 saved in 0.46 seconds.
# Data for RZLV in 2016 saved in 0.41 seconds.
# Data for RZTK in 2016 saved in 0.55 seconds.
# Data for RZUG in 2016 saved in 0.40 seconds.
# Data for RZUS in 2016 saved in 0.41 seconds.
# Data for SBT in 2016 saved in 0.56 seconds.
# Data for SDOM in 2016 saved in 0.40 seconds.
# Data for SIL in 2016 saved in 0.41 seconds.
# Data for SKON in 2016 saved in 0.49 seconds.
# Data for SKP in 2016 saved in 0.22 seconds.
# Data for SLAV in 2016 saved in 0.41 seconds.
# No data found for SNBT in 2016
# No data found for SNBTO in 2016
# Data for SOLN in 2016 saved in 0.52 seconds.
# Data for SPAZ in 2016 saved in 0.41 seconds.
# Data for SPAZP in 2016 saved in 0.42 seconds.
# Data for SPOL in 2016 saved in 0.52 seconds.
# Data for SSPR in 2016 saved in 0.40 seconds.
# Data for STB in 2016 saved in 0.49 seconds.
# Data for STBP in 2016 saved in 0.69 seconds.
# Data for STIL in 2016 saved in 0.54 seconds.
# Data for STOK in 2016 saved in 0.53 seconds.
# Data for TAJM in 2016 saved in 0.63 seconds.
# No data found for TBKO in 2016
# Data for TEAL in 2016 saved in 0.40 seconds.
# Data for TEHN in 2016 saved in 0.39 seconds.
# Data for TEL in 2016 saved in 0.54 seconds.
# Data for TETE in 2016 saved in 0.39 seconds.
# Data for TIKV in 2016 saved in 0.41 seconds.
# Data for TKPR in 2016 saved in 0.54 seconds.
# Data for TKVS in 2016 saved in 0.40 seconds.
# Data for TNB in 2016 saved in 0.40 seconds.
# Data for TRDB in 2016 saved in 0.54 seconds.
# Data for TRPS in 2016 saved in 0.42 seconds.
# Data for TRUB in 2016 saved in 0.24 seconds.
# Data for TSMP in 2016 saved in 0.43 seconds.
# No data found for TSZS in 2016
# Data for TTK in 2016 saved in 0.56 seconds.
# No data found for TTKO in 2016
# Data for UNI in 2016 saved in 0.41 seconds.
# Data for USJE in 2016 saved in 0.56 seconds.
# No data found for VARG in 2016
# No data found for VFPM in 2016
# Data for VITA in 2016 saved in 0.38 seconds.
# Data for VROS in 2016 saved in 0.41 seconds.
# No data found for VSC in 2016
# Data for VTKS in 2016 saved in 0.54 seconds.
# Data for ZAS in 2016 saved in 0.40 seconds.
# Data for ZILU in 2016 saved in 0.58 seconds.
# Data for ZILUP in 2016 saved in 0.78 seconds.
# Data for ZIMS in 2016 saved in 0.58 seconds.
# Data for ZKAR in 2016 saved in 0.53 seconds.
# Data for ZPKO in 2016 saved in 0.66 seconds.
# Data for ZPOG in 2016 saved in 0.44 seconds.
# Data for ZUAS in 2016 saved in 0.44 seconds.
# Data for ADIN in 2015 saved in 0.53 seconds.
# Data for ALK in 2015 saved in 0.42 seconds.
# Data for ALKB in 2015 saved in 0.42 seconds.
# No data found for AMBR in 2015
# Data for AMEH in 2015 saved in 0.57 seconds.
# Data for APTK in 2015 saved in 0.43 seconds.
# Data for ATPP in 2015 saved in 0.40 seconds.
# Data for AUMK in 2015 saved in 0.66 seconds.
# Data for BANA in 2015 saved in 0.40 seconds.
# Data for BGOR in 2015 saved in 0.42 seconds.
# Data for BIKF in 2015 saved in 0.56 seconds.
# Data for BIM in 2015 saved in 0.41 seconds.
# Data for BLTU in 2015 saved in 0.40 seconds.
# Data for CBNG in 2015 saved in 0.51 seconds.
# Data for CDHV in 2015 saved in 0.40 seconds.
# Data for CEVI in 2015 saved in 0.40 seconds.
# Data for CKB in 2015 saved in 0.58 seconds.
# No data found for CKBKO in 2015
# Data for DEBA in 2015 saved in 0.39 seconds.
# Data for DIMI in 2015 saved in 0.42 seconds.
# Data for EDST in 2015 saved in 0.76 seconds.
# Data for ELMA in 2015 saved in 0.55 seconds.
# Data for ELNC in 2015 saved in 0.56 seconds.
# Data for ENER in 2015 saved in 0.68 seconds.
# No data found for ENSA in 2015
# Data for EUHA in 2015 saved in 0.39 seconds.
# Data for EUMK in 2015 saved in 0.43 seconds.
# Data for EVRO in 2015 saved in 0.64 seconds.
# Data for FAKM in 2015 saved in 0.42 seconds.
# Data for FERS in 2015 saved in 0.42 seconds.
# No data found for FKTL in 2015
# Data for FROT in 2015 saved in 0.59 seconds.
# Data for FUBT in 2015 saved in 0.40 seconds.
# Data for GALE in 2015 saved in 0.40 seconds.
# Data for GDKM in 2015 saved in 0.62 seconds.
# Data for GECK in 2015 saved in 0.39 seconds.
# Data for GECT in 2015 saved in 0.40 seconds.
# Data for GIMS in 2015 saved in 0.52 seconds.
# Data for GRDN in 2015 saved in 0.39 seconds.
# Data for GRNT in 2015 saved in 0.39 seconds.
# Data for GRSN in 2015 saved in 0.52 seconds.
# Data for GRZD in 2015 saved in 0.39 seconds.
# Data for GTC in 2015 saved in 0.38 seconds.
# Data for GTRG in 2015 saved in 0.52 seconds.
# Data for IJUG in 2015 saved in 0.41 seconds.
# Data for INB in 2015 saved in 0.39 seconds.
# Data for INHO in 2015 saved in 0.52 seconds.
# No data found for INOV in 2015
# Data for INPR in 2015 saved in 1.25 seconds.
# Data for INTP in 2015 saved in 0.52 seconds.
# Data for JAKO in 2015 saved in 0.55 seconds.
# Data for JUSK in 2015 saved in 0.44 seconds.
# Data for KARO in 2015 saved in 0.40 seconds.
# Data for KDFO in 2015 saved in 0.58 seconds.
# Data for KJUBI in 2015 saved in 0.40 seconds.
# No data found for KKST in 2015
# Data for KLST in 2015 saved in 0.40 seconds.
# Data for KMB in 2015 saved in 0.54 seconds.
# Data for KMPR in 2015 saved in 0.41 seconds.
# Data for KOMU in 2015 saved in 0.38 seconds.
# Data for KONF in 2015 saved in 0.52 seconds.
# Data for KONZ in 2015 saved in 0.39 seconds.
# Data for KORZ in 2015 saved in 0.41 seconds.
# Data for KPSS in 2015 saved in 0.54 seconds.
# Data for KULT in 2015 saved in 0.40 seconds.
# Data for KVAS in 2015 saved in 0.41 seconds.
# Data for LAJO in 2015 saved in 0.55 seconds.
# Data for LHND in 2015 saved in 0.44 seconds.
# Data for LOTO in 2015 saved in 0.43 seconds.
# Data for LOZP in 2015 saved in 0.57 seconds.
# No data found for MAGP in 2015
# Data for MAKP in 2015 saved in 0.57 seconds.
# Data for MAKS in 2015 saved in 0.52 seconds.
# Data for MB in 2015 saved in 0.72 seconds.
# Data for MERM in 2015 saved in 0.58 seconds.
# Data for MKSD in 2015 saved in 0.39 seconds.
# Data for MLKR in 2015 saved in 0.58 seconds.
# Data for MODA in 2015 saved in 0.41 seconds.
# Data for MPOL in 2015 saved in 0.41 seconds.
# Data for MPT in 2015 saved in 0.55 seconds.
# Data for MPTE in 2015 saved in 0.42 seconds.
# Data for MTUR in 2015 saved in 0.43 seconds.
# Data for MZHE in 2015 saved in 0.53 seconds.
# Data for MZPU in 2015 saved in 0.40 seconds.
# Data for NEME in 2015 saved in 0.40 seconds.
# Data for NOSK in 2015 saved in 0.53 seconds.
# Data for OBPP in 2015 saved in 0.38 seconds.
# Data for OILK in 2015 saved in 0.41 seconds.
# Data for OKTA in 2015 saved in 0.53 seconds.
# No data found for OMOS in 2015
# No data found for OPFO in 2015
# Data for OPTK in 2015 saved in 0.39 seconds.
# Data for ORAN in 2015 saved in 0.39 seconds.
# Data for OSPO in 2015 saved in 0.57 seconds.
# Data for OTEK in 2015 saved in 0.42 seconds.
# Data for PELK in 2015 saved in 0.42 seconds.
# Data for PGGV in 2015 saved in 0.51 seconds.
# Data for PKB in 2015 saved in 0.41 seconds.
# Data for POPK in 2015 saved in 0.53 seconds.
# Data for PPIV in 2015 saved in 0.68 seconds.
# Data for PROD in 2015 saved in 0.54 seconds.
# No data found for PROT in 2015
# Data for PTRS in 2015 saved in 0.53 seconds.
# Data for RADE in 2015 saved in 0.55 seconds.
# Data for REPL in 2015 saved in 0.39 seconds.
# Data for RIMI in 2015 saved in 0.39 seconds.
# Data for RINS in 2015 saved in 0.58 seconds.
# Data for RZEK in 2015 saved in 0.45 seconds.
# Data for RZIT in 2015 saved in 0.44 seconds.
# Data for RZIZ in 2015 saved in 0.54 seconds.
# Data for RZLE in 2015 saved in 0.41 seconds.
# Data for RZLV in 2015 saved in 0.39 seconds.
# Data for RZTK in 2015 saved in 0.57 seconds.
# Data for RZUG in 2015 saved in 0.39 seconds.
# Data for RZUS in 2015 saved in 0.41 seconds.
# Data for SBT in 2015 saved in 0.53 seconds.
# Data for SDOM in 2015 saved in 0.39 seconds.
# Data for SIL in 2015 saved in 0.42 seconds.
# Data for SKON in 2015 saved in 0.55 seconds.
# Data for SKP in 2015 saved in 0.43 seconds.
# Data for SLAV in 2015 saved in 0.41 seconds.
# No data found for SNBT in 2015
# No data found for SNBTO in 2015
# Data for SOLN in 2015 saved in 0.62 seconds.
# Data for SPAZ in 2015 saved in 0.39 seconds.
# Data for SPAZP in 2015 saved in 0.44 seconds.
# Data for SPOL in 2015 saved in 0.71 seconds.
# Data for SSPR in 2015 saved in 0.55 seconds.
# Data for STB in 2015 saved in 0.55 seconds.
# Data for STBP in 2015 saved in 0.68 seconds.
# Data for STIL in 2015 saved in 0.41 seconds.
# Data for STOK in 2015 saved in 0.39 seconds.
# Data for TAJM in 2015 saved in 0.54 seconds.
# Data for TBKO in 2015 saved in 0.44 seconds.
# Data for TEAL in 2015 saved in 0.42 seconds.
# Data for TEHN in 2015 saved in 0.53 seconds.
# Data for TEL in 2015 saved in 0.42 seconds.
# Data for TETE in 2015 saved in 0.43 seconds.
# Data for TIKV in 2015 saved in 0.52 seconds.
# Data for TKPR in 2015 saved in 0.41 seconds.
# Data for TKVS in 2015 saved in 0.39 seconds.
# Data for TNB in 2015 saved in 0.52 seconds.
# Data for TRDB in 2015 saved in 0.40 seconds.
# Data for TRPS in 2015 saved in 0.42 seconds.
# Data for TRUB in 2015 saved in 0.57 seconds.
# Data for TSMP in 2015 saved in 0.39 seconds.
# Data for TSZS in 2015 saved in 0.41 seconds.
# Data for TTK in 2015 saved in 0.39 seconds.
# No data found for TTKO in 2015
# Data for UNI in 2015 saved in 0.42 seconds.
# Data for USJE in 2015 saved in 0.38 seconds.
# Data for VARG in 2015 saved in 0.53 seconds.
# No data found for VFPM in 2015
# Data for VITA in 2015 saved in 0.53 seconds.
# Data for VROS in 2015 saved in 0.53 seconds.
# Data for VSC in 2015 saved in 0.72 seconds.
# Data for VTKS in 2015 saved in 0.54 seconds.
# Data for ZAS in 2015 saved in 0.39 seconds.
# Data for ZILU in 2015 saved in 0.53 seconds.
# Data for ZILUP in 2015 saved in 0.41 seconds.
# Data for ZIMS in 2015 saved in 0.39 seconds.
# Data for ZKAR in 2015 saved in 0.52 seconds.
# Data for ZPKO in 2015 saved in 0.42 seconds.
# Data for ZPOG in 2015 saved in 0.38 seconds.
# Data for ZUAS in 2015 saved in 0.52 seconds.
# Script completed in 810.33 seconds.
